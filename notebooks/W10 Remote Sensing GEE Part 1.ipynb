# %% [markdown]
# # Introduction to Remote Sensing with Python via Google Earth Engine
#
# ## Part 1
#
#
# Note: the materials are borrowed from https://github.com/yohman/workshop-remote-sensing/tree/main
#
#
# 9 things about Landsat: https://youtu.be/DGE-N8_LQBo

# %% [markdown]
# ## Landsat
#
# Landsat is the first "civilian Earth observation satellite" launched in 1972, a collaboration between the Department of the Interior, NASA, and the Department of Agriculture.
#
# At over 40 years, the Landsat series of satellites provides the longest temporal record of moderate resolution multispectral data of the Earth’s surface on a global basis. The Landsat record has remained remarkably unbroken, proving a unique resource to assist a broad range of specialists in managing the world’s food, water, forests, and other natural resources for a growing world population. It is a record unmatched in quality, detail, coverage, and value. Source: USGS
#
# - [NASA's Landsat page](https://www.nasa.gov/mission_pages/landsat/overview/index.html)
# - [USGS's Landsat page](https://www.usgs.gov/core-science-systems/nli/landsat)
# - [Landsat Explorer](https://livingatlas.arcgis.com/landsatexplorer/#mapCenter=18.47600%2C-23.91400%2C11.692&mode=dynamic&mainScene=%7CGeology+for+Visualization%7C)

# %% [markdown]
# ## How to access landsat data
#
# - [USGS Earth Explorer](https://earthexplorer.usgs.gov/)
# - [Amazon AWS Open Data](https://registry.opendata.aws/landsat-8/)
# - [Google Earth Engine](https://developers.google.com/earth-engine/datasets/catalog/landsat-8)

# %% [markdown]
# ## Finding satellite image of the 2018 Camp Fire
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/b/b1/Camp_Fire_oli_2018312_Landsat.jpg/800px-Camp_Fire_oli_2018312_Landsat.jpg">
#
# The Camp Fire was the deadliest and most destructive wildfire in California's history, and the most expensive natural disaster in the world in 2018 in terms of insured losses.
#
# - https://en.wikipedia.org/wiki/Camp_Fire_(2018)

# %% [markdown]
# ## Google Earth Engine
#
# **Google Earth Engine (GEE)** is a cloud-based platform designed for processing and analyzing geospatial data on a large scale.
#
# It provides access to a vast collection of public datasets, including satellite imagery, aerial photography, weather data, and other geospatial information. GEE allows users to run computations on these datasets using its powerful cloud infrastructure, making it ideal for environmental monitoring, research, and analysis.

# %% [markdown]
# ### The Workflow
#
# In this lab, we will do the following:
#
# - Use Google Earth Engine's Python API
# - define an AOI (area of interest) in the Northern California's Butte County
# - import multiple Landsat images from the dates before and after the Camp Fire
# - determine which images are best for analysis
# - create various NDVI map outputs to assess the amount of fire damage

# %% [markdown]
# ## Python libraries in this workshop
#
# Install google earth engine python interface using
#
# `pip install earthengine-api`

# %%
#pip install earthengine-api

#or $pip install earthengine-api

# %% [markdown]
# ## Import libraries

# %%
# the regulars
import pandas as pd
import geopandas as gpd

# earth engine
import ee

# allow images to display in the notebook
from IPython.display import Image

# %% [markdown]
# ## Authenticate Earth Engine
#
# The authentication process only applies once. Once successful, it will store a credential file on your local computer.

# %%
# Trigger the authentication flow.
ee.Authenticate()

# Initialize the library.
ee.Initialize()

# %% [markdown]
# For this lab, we will use Google Earth Engine's "USGS Landsat 8 Level 2, Collection 2, Tier 1"
#
# - [EE Landsat 8](https://developers.google.com/earth-engine/datasets/catalog/LANDSAT_LC08_C02_T1_L2)
#
# You can also:
#
# - `.filterBounds()` method allows you to filter by location
# - `.filterDate()` allows you to filter by date

# %% [markdown]
# ## Define filters

# %%
# coordinates of the Camp Fire
lat =  39.444012
lon = -121.833619

# point of interest as an ee.Geometry
poi = ee.Geometry.Point(lon,lat)

# start date of range to filter for
start_date = '2018-10-01'

# end date
end_date = '2019-01-31'

# %% [markdown]
# ## Get Landsat 8 data
#
# See all the other datasets here: https://developers.google.com/earth-engine/datasets/

# %%
# get the satellite data
landsat = ee.ImageCollection("LANDSAT/LC08/C02/T1_L2")\
            .filterBounds(poi)\
            .filterDate(start_date,end_date)

# %%
# how many images did we get?

print('Total number:', landsat.size().getInfo())
# Out:
# Total number: 8

# %%
# information about the first image in our collection
landsat.first().getInfo()
# Out:
# {'type': 'Image',
#  'bands': [{'id': 'SR_B1',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [7661, 7791],
#    'crs': 'EPSG:32610',
#    'crs_transform': [30, 0, 500385, 0, -30, 4423215]},
#   {'id': 'SR_B2',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [7661, 7791],
#    'crs': 'EPSG:32610',
#    'crs_transform': [30, 0, 500385, 0, -30, 4423215]},
#   {'id': 'SR_B3',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [7661, 7791],
#    'crs': 'EPSG:32610',
#    'crs_transform': [30, 0, 500385, 0, -30, 4423215]},
#   {'id': 'SR_B4',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [7661, 7791],
#    'crs': 'EPSG:32610',
#    'crs_transform': [30, 0, 500385, 0, -30, 4423215]},
#   {'id': 'SR_B5',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [7661, 7791],
#    'crs': 'EPSG:32610',
#    'crs_transform': [30, 0, 500385, 0, -30, 4423215]},
#   {'id': 'SR_B6',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [7661, 7791],
#    'crs': 'EPSG:32610',
#    'crs_transform': [30, 0, 500385, 0, -30, 4423215]},
#   {'id': 'SR_B7',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [7661, 7791],
#    'crs': 'EPSG:32610',
#    'crs_transform': [30, 0, 500385, 0, -30, 4423215]},
#   {'id': 'SR_QA_AEROSOL',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 255},
#    'dimensions': [7661, 7791],
#    'crs': 'EPSG:32610',
#    'crs_transform': [30, 0, 500385, 0, -30, 4423215]},
#   {'id': 'ST_B10',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [7661, 7791],
#    'crs': 'EPSG:32610',
#    'crs_transform': [30, 0, 500385, 0, -30, 4423215]},
#   {'id': 'ST_ATRAN',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': -32768,
#     'max': 32767},
#    'dimensions': [7661, 7791],
#    'crs': 'EPSG:32610',
#    'crs_transform': [30, 0, 500385, 0, -30, 4423215]},
#   {'id': 'ST_CDIST',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': -32768,
#     'max': 32767},
#    'dimensions': [7661, 7791],
#    'crs': 'EPSG:32610',
#    'crs_transform': [30, 0, 500385, 0, -30, 4423215]},
#   {'id': 'ST_DRAD',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': -32768,
#     'max': 32767},
#    'dimensions': [7661, 7791],
#    'crs': 'EPSG:32610',
#    'crs_transform': [30, 0, 500385, 0, -30, 4423215]},
#   {'id': 'ST_EMIS',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': -32768,
#     'max': 32767},
#    'dimensions': [7661, 7791],
#    'crs': 'EPSG:32610',
#    'crs_transform': [30, 0, 500385, 0, -30, 4423215]},
#   {'id': 'ST_EMSD',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': -32768,
#     'max': 32767},
#    'dimensions': [7661, 7791],
#    'crs': 'EPSG:32610',
#    'crs_transform': [30, 0, 500385, 0, -30, 4423215]},
#   {'id': 'ST_QA',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': -32768,
#     'max': 32767},
#    'dimensions': [7661, 7791],
#    'crs': 'EPSG:32610',
#    'crs_transform': [30, 0, 500385, 0, -30, 4423215]},
#   {'id': 'ST_TRAD',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': -32768,
#     'max': 32767},
#    'dimensions': [7661, 7791],
#    'crs': 'EPSG:32610',
#    'crs_transform': [30, 0, 500385, 0, -30, 4423215]},
#   {'id': 'ST_URAD',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': -32768,
#     'max': 32767},
#    'dimensions': [7661, 7791],
#    'crs': 'EPSG:32610',
#    'crs_transform': [30, 0, 500385, 0, -30, 4423215]},
#   {'id': 'QA_PIXEL',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [7661, 7791],
#    'crs': 'EPSG:32610',
#    'crs_transform': [30, 0, 500385, 0, -30, 4423215]},
#   {'id': 'QA_RADSAT',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [7661, 7791],
#    'crs': 'EPSG:32610',
#    'crs_transform': [30, 0, 500385, 0, -30, 4423215]}],
#  'version': 1629895720593702,
#  'id': 'LANDSAT/LC08/C02/T1_L2/LC08_044033_20181007',
#  'properties': {'DATA_SOURCE_ELEVATION': 'GLS2000',
#   'WRS_TYPE': 2,
#   'REFLECTANCE_ADD_BAND_1': -0.2,
#   'REFLECTANCE_ADD_BAND_2': -0.2,
#   'DATUM': 'WGS84',
#   'REFLECTANCE_ADD_BAND_3': -0.2,
#   'REFLECTANCE_ADD_BAND_4': -0.2,
#   'REFLECTANCE_ADD_BAND_5': -0.2,
#   'REFLECTANCE_ADD_BAND_6': -0.2,
#   'REFLECTANCE_ADD_BAND_7': -0.2,
#   'system:footprint': {'type': 'LinearRing',
#    'coordinates': [[-120.96945987441705, 37.85396978622024],
#     [-120.91758272903665, 37.84360095586152],
#     [-120.91091374989027, 37.84230108097053],
#     [-120.91032102754652, 37.84319081260253],
#     [-120.90026375188283, 37.87485737375912],
#     [-120.88601930375758, 37.91975025888466],
#     [-120.87475935368046, 37.95523294042605],
#     [-120.76830993328551, 38.28982473972092],
#     [-120.60616669159636, 38.7956184110626],
#     [-120.46920219411804, 39.21870028030481],
#     [-120.35829507594683, 39.55929948514903],
#     [-120.358940626908, 39.55982942717467],
#     [-120.3773619745756, 39.563471697339374],
#     [-121.13362575572384, 39.70944332250483],
#     [-122.47094597878574, 39.95415252966201],
#     [-122.47146231484521, 39.953369391342086],
#     [-122.47255137997769, 39.95009912185038],
#     [-122.97579676306593, 38.235899800160965],
#     [-122.97515026884432, 38.23538966186662],
#     [-122.83153924692401, 38.209342252115945],
#     [-120.96945987441705, 37.85396978622024]]},
#   'REFLECTIVE_SAMPLES': 7661,
#   'GROUND_CONTROL_POINTS_VERSION': 5,
#   'SUN_AZIMUTH': 156.37136574,
#   'DATA_SOURCE_TIRS_STRAY_LIGHT_CORRECTION': 'TIRS',
#   'UTM_ZONE': 10,
#   'DATE_ACQUIRED': '2018-10-07',
#   'ELLIPSOID': 'WGS84',
#   'system:time_end': 1538937928212,
#   'DATA_SOURCE_PRESSURE': 'Calculated',
#   'LANDSAT_PRODUCT_ID': 'LC08_L2SP_044033_20181007_20200830_02_T1',
#   'STATION_ID': 'LGN',
#   'TEMPERATURE_ADD_BAND_ST_B10': 149,
#   'DATA_SOURCE_REANALYSIS': 'GEOS-5 FP-IT',
#   'REFLECTANCE_MULT_BAND_7': 2.75e-05,
#   'system:time_start': 1538937928212,
#   'REFLECTANCE_MULT_BAND_6': 2.75e-05,
#   'L1_PROCESSING_LEVEL': 'L1TP',
#   'PROCESSING_SOFTWARE_VERSION': 'LPGS_15.3.1c',
#   'L1_DATE_PRODUCT_GENERATED': '2020-08-30T22:04:06Z',
#   'ORIENTATION': 'NORTH_UP',
#   'REFLECTANCE_MULT_BAND_1': 2.75e-05,
#   'WRS_ROW': 33,
#   'REFLECTANCE_MULT_BAND_3': 2.75e-05,
#   'REFLECTANCE_MULT_BAND_2': 2.75e-05,
#   'TARGET_WRS_ROW': 33,
#   'REFLECTANCE_MULT_BAND_5': 2.75e-05,
#   'REFLECTANCE_MULT_BAND_4': 2.75e-05,
#   'THERMAL_LINES': 7791,
#   'TIRS_SSM_POSITION_STATUS': 'ESTIMATED',
#   'GRID_CELL_SIZE_THERMAL': 30,
#   'IMAGE_QUALITY_TIRS': 9,
#   'TRUNCATION_OLI': 'UPPER',
#   'NADIR_OFFNADIR': 'NADIR',
#   'CLOUD_COVER': 0.05,
#   'REQUEST_ID': 'L2',
#   'EARTH_SUN_DISTANCE': 0.9993983,
#   'GEOMETRIC_RMSE_VERIFY': 3.028,
#   'TIRS_SSM_MODEL': 'FINAL',
#   'COLLECTION_CATEGORY': 'T1',
#   'SCENE_CENTER_TIME': '18:45:28.2127380Z',
#   'GRID_CELL_SIZE_REFLECTIVE': 30,
#   'SUN_ELEVATION': 42.62885674,
#   'ALGORITHM_SOURCE_SURFACE_TEMPERATURE': 'st_1.3.0',
#   'TEMPERATURE_MAXIMUM_BAND_ST_B10': 372.999941,
#   'CLOUD_COVER_LAND': 0.05,
#   'GEOMETRIC_RMSE_MODEL': 5.915,
#   'ROLL_ANGLE': -0.001,
#   'COLLECTION_NUMBER': 2,
#   'DATE_PRODUCT_GENERATED': 1598825983000,
#   'L1_REQUEST_ID': 'L2',
#   'DATA_SOURCE_OZONE': 'MODIS',
#   'SATURATION_BAND_1': 'Y',
#   'DATA_SOURCE_WATER_VAPOR': 'MODIS',
#   'SATURATION_BAND_2': 'Y',
#   'SATURATION_BAND_3': 'Y',
#   'IMAGE_QUALITY_OLI': 9,
#   'SATURATION_BAND_4': 'Y',
#   'LANDSAT_SCENE_ID': 'LC80440332018280LGN00',
#   'SATURATION_BAND_5': 'Y',
#   'MAP_PROJECTION': 'UTM',
#   'SATURATION_BAND_6': 'Y',
#   'SENSOR_ID': 'OLI_TIRS',
#   'SATURATION_BAND_7': 'Y',
#   'SATURATION_BAND_8': 'N',
#   'WRS_PATH': 44,
#   'SATURATION_BAND_9': 'N',
#   'TARGET_WRS_PATH': 44,
#   'L1_PROCESSING_SOFTWARE_VERSION': 'LPGS_15.3.1c',
#   'TEMPERATURE_MULT_BAND_ST_B10': 0.00341802,
#   'L1_LANDSAT_PRODUCT_ID': 'LC08_L1TP_044033_20181007_20200830_02_T1',
#   'PROCESSING_LEVEL': 'L2SP',
#   'ALGORITHM_SOURCE_SURFACE_REFLECTANCE': 'LaSRC_1.5.0',
#   'GROUND_CONTROL_POINTS_MODEL': 1318,
#   'SPACECRAFT_ID': 'LANDSAT_8',
#   'TEMPERATURE_MINIMUM_BAND_ST_B10': 149.003418,
#   'GEOMETRIC_RMSE_MODEL_Y': 4.945,
#   'REFLECTIVE_LINES': 7791,
#   'GEOMETRIC_RMSE_MODEL_X': 3.246,
#   'THERMAL_SAMPLES': 7661,
#   'system:asset_size': 965138511,
#   'DATA_SOURCE_AIR_TEMPERATURE': 'MODIS',
#   'GROUND_CONTROL_POINTS_VERIFY': 416,
#   'system:index': 'LC08_044033_20181007'}}

# %%
# what about cloud cover of our first image?
landsat.first().get('CLOUD_COVER').getInfo()
# Out:
# 0.05

# %%
# when was this image taken?
landsat.first().get('DATE_ACQUIRED').getInfo()
# Out:
# '2018-10-07'

# %% [markdown]
# ## Bands
# <img src="https://d9-wret.s3.us-west-2.amazonaws.com/assets/palladium/production/s3fs-public/thumbnails/image/Landsat%208%20band%20designations.jpg" width=800>
#
#
#
# [Source: USGS](https://www.usgs.gov/media/images/landsat-8-band-designations)

# %%
# what bands did we get?
landsat.first().bandNames().getInfo()
# Out:
# ['SR_B1',
#  'SR_B2',
#  'SR_B3',
#  'SR_B4',
#  'SR_B5',
#  'SR_B6',
#  'SR_B7',
#  'SR_QA_AEROSOL',
#  'ST_B10',
#  'ST_ATRAN',
#  'ST_CDIST',
#  'ST_DRAD',
#  'ST_EMIS',
#  'ST_EMSD',
#  'ST_QA',
#  'ST_TRAD',
#  'ST_URAD',
#  'QA_PIXEL',
#  'QA_RADSAT']

# %%
# put the images in a list
landsat_list = landsat.toList(landsat.size());

# %% [markdown]
# ## Display satellite image
#
# - [What are the min/max values?](https://gis.stackexchange.com/questions/304180/what-are-the-min-and-max-values-of-map-addlayer-on-google-earth-engine)

# %%
# set some parameters for the images
parameters = {
                'min': 7000,
                'max': 16000,
                'dimensions': 800, # square size in pixels
                'bands': ['SR_B4', 'SR_B3', 'SR_B2'] # bands to display (r,g,b)
             }

# %%
# create an empty data container
data = []

# loop through each image and display it
for i in range(landsat.size().getInfo()):

    # when was this image taken?
    date = ee.Image(landsat_list.get(i)).get('DATE_ACQUIRED').getInfo()
    
    # cloud cover
    cloud = ee.Image(landsat_list.get(i)).get('CLOUD_COVER').getInfo()
    
    # print the image info
    print('Image #',i,date,'Cloud cover:',cloud)
    
    # display the image
    display(Image(url = ee.Image(landsat_list.get(i)).getThumbUrl(parameters)))

    # data to list
    this_data = [i,date,cloud]

    # append the data 
    data.append(this_data)
    

# Create the pandas DataFrame
df = pd.DataFrame(data, columns = ['Image #', 'Date', 'Cloud Cover'])
# Out:
# Image # 0 2018-10-07 Cloud cover: 0.05
# <img src="https://earthengine.googleapis.com/v1/projects/875075998925/thumbnails/83fce047a989dff287476aab7f013825-4159d91c7e965ffac365badd2d49a049:getPixels"/>
# Image # 1 2018-10-23 Cloud cover: 73.04
# <img src="https://earthengine.googleapis.com/v1/projects/875075998925/thumbnails/f06fbe5dd3beaa31ec3df94636f5b906-46cb509a8fbc4705e4533df35c97aeab:getPixels"/>
# Image # 2 2018-11-08 Cloud cover: 11.83
# <img src="https://earthengine.googleapis.com/v1/projects/875075998925/thumbnails/3183e00e2d6d0aa183e7f22d5b9937af-e1075e65c37ec5539bee7060cf960195:getPixels"/>
# Image # 3 2018-11-24 Cloud cover: 67.16
# <img src="https://earthengine.googleapis.com/v1/projects/875075998925/thumbnails/4a51b4e57cf5a7edd630e158853c379c-54629592cf80d9714dcc83354bbf73ac:getPixels"/>
# Image # 4 2018-12-10 Cloud cover: 56.09
# <img src="https://earthengine.googleapis.com/v1/projects/875075998925/thumbnails/6cf06c37393edeedd65dd8ad3e97f816-61741d8d244d1e3970e2eddc4c49a963:getPixels"/>
# Image # 5 2018-12-26 Cloud cover: 5.99
# <img src="https://earthengine.googleapis.com/v1/projects/875075998925/thumbnails/14ae245ba7e596dcfb4df0fbf04ba55d-86b066b3a860007fb77ab5155cf97892:getPixels"/>
# Image # 6 2019-01-11 Cloud cover: 80.06
# <img src="https://earthengine.googleapis.com/v1/projects/875075998925/thumbnails/2516bab4c9c3415887fd6b73507eca3a-a1c4883cd41b1bcedc45be59c7074074:getPixels"/>
# Image # 7 2019-01-27 Cloud cover: 5.21
# <img src="https://earthengine.googleapis.com/v1/projects/875075998925/thumbnails/e7b3822508e98cd614da412e7eb8e09e-f4491d36d354b29446bb27fa0c139b40:getPixels"/>

# %%
# our data in a dataframe
df
# Out:
#    Image #        Date  Cloud Cover
# 0        0  2018-10-07         0.05
# 1        1  2018-10-23        73.04
# 2        2  2018-11-08        11.83
# 3        3  2018-11-24        67.16
# 4        4  2018-12-10        56.09
# 5        5  2018-12-26         5.99
# 6        6  2019-01-11        80.06
# 7        7  2019-01-27         5.21

# %% [markdown]
# ## Selecting images, zooming in
# Now that we have inspected our collection of images, we can pick and choose which ones are relevant for our study. Ideally, we want to have images for before and after the fire to be able to assess the level of damage.
#
# We also want to create an ROI (region of interest) and zoom in to the area of interest. We do so by appying a 20km buffer around our POI.

# %%
# create a list of images we want (before, during, after)
landsat_sequence = [0,2,5]

# %%
# Define a region of interest with a buffer zone of 20 km
roi = poi.buffer(20000) # meters

# %%
parameters = {
                'min': 6000,
                'max': 16000,
                'dimensions': 800,
                'bands': ['SR_B4', 'SR_B3', 'SR_B2'],
                'region':roi
             }

# %%
for i in landsat_sequence:
    
    # when was this image taken?
    date = ee.Image(landsat_list.get(i)).get('DATE_ACQUIRED').getInfo()

    # cloud cover
    cloud = ee.Image(landsat_list.get(i)).get('CLOUD_COVER').getInfo()
    
    print('Image #',i,date,'Cloud cover:',cloud)
    
    display(Image(url = ee.Image(landsat_list.get(i)).getThumbUrl(parameters)))
# Out:
# Image # 0 2018-10-07 Cloud cover: 0.05
# <img src="https://earthengine.googleapis.com/v1/projects/875075998925/thumbnails/9cbd09c359772d3e8ded8770787c2cb1-38a01649c16b88dd1af662e0072733f8:getPixels"/>
# Image # 2 2018-11-08 Cloud cover: 11.83
# <img src="https://earthengine.googleapis.com/v1/projects/875075998925/thumbnails/39927ca04abab2f0cd41ba19b4c048ba-3eb7caf0aee835103ecb144c9425c68d:getPixels"/>
# Image # 5 2018-12-26 Cloud cover: 5.99
# <img src="https://earthengine.googleapis.com/v1/projects/875075998925/thumbnails/d347118da189dfc6279bbb65e4a86eb0-6b429d2aff5381e8429828297dccdae0:getPixels"/>

# %% [markdown]
# <div class="alert alert-info">
# Take a moment to inspect the three images above. What do they tell you? What do they NOT tell you?
# </div>

# %% [markdown]
# ## Normalized Difference Vegetation Index (NDVI)
#
# The normalized difference vegetation index (NDVI) is a simple graphical indicator that can be used to analyze remote sensing measurements, often from a space platform, assessing whether or not the target being observed contains live green vegetation.
#
# <img src="https://mapscaping.com/wp-content/uploads/2024/09/935ab8e9-3401-4733-b687-c14af67425de.webp" width=600>

# %% [markdown]
# ### Calculating NDVI in Google Earth Engine
#
# - https://developers.google.com/earth-engine/tutorials/tutorial_api_06

# %%
# ndvi palette: red is low, green is high vegetation
palette = ['red', 'yellow', 'green']

ndvi_parameters = {'min': 0,
                   'max': 0.4,
                   'dimensions': 512,
                   'palette': palette,
                   'region': roi}

# %%
for i in landsat_sequence:

    # when was this image taken?
    date = ee.Image(landsat_list.get(i)).get('DATE_ACQUIRED').getInfo()
    
    # print some information
    print('Image #',i,date)
    
    # display the image
    display(Image(url=ee.Image(landsat_list.get(i)).normalizedDifference(['SR_B5', 'SR_B4']).getThumbUrl(ndvi_parameters)))
# Out:
# Image # 0 2018-10-07
# <img src="https://earthengine.googleapis.com/v1/projects/875075998925/thumbnails/0eb4b49dd2ede2bbe21acadbb800e88a-54c7631751e28e31ca54789fa17a580a:getPixels"/>
# Image # 2 2018-11-08
# <img src="https://earthengine.googleapis.com/v1/projects/875075998925/thumbnails/f6c49d87bd95b793dda6415d92233536-337d2fb8c31bf01d9c8dab9970d7beb5:getPixels"/>
# Image # 5 2018-12-26
# <img src="https://earthengine.googleapis.com/v1/projects/875075998925/thumbnails/1bde3339cd163245dec9f00d4d71fba7-607e92413ea143573c7ed7578974800d:getPixels"/>

# %% [markdown]
# ## Folium
#
# Google earth engine works with folium, see here for more examples:
# - https://developers.google.com/earth-engine/tutorials/community/intro-to-python-api-guiattard?hl=en#interactive_mapping_using_folium

# %%
# a simple folium map
import folium

m = folium.Map(location=[lat,lon])
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0dc1d9df1c2cb11217b98aec78b7c183 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0dc1d9df1c2cb11217b98aec78b7c183&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0dc1d9df1c2cb11217b98aec78b7c183 = L.map(
#                 &quot;map_0dc1d9df1c2cb11217b98aec78b7c183&quot;,
#                 {
#                     center: [39.444012, -121.833619],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d5f1f1ae0521081e0638dbc31856c3f2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d5f1f1ae0521081e0638dbc31856c3f2.addTo(map_0dc1d9df1c2cb11217b98aec78b7c183);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Google function that allows ee layers on folium
def add_ee_layer(self, ee_image_object, vis_params, name):
    """Adds a method for displaying Earth Engine image tiles to folium map."""
    map_id_dict = ee.Image(ee_image_object).getMapId(vis_params)
    folium.raster_layers.TileLayer(
        tiles=map_id_dict['tile_fetcher'].url_format,
        attr='Map Data &copy; <a href="https://earthengine.google.com/">Google Earth Engine</a>',
        name=name,
        overlay=True,
        control=True
    ).add_to(self)

# Add Earth Engine drawing method to folium
folium.Map.add_ee_layer = add_ee_layer

# %%
# Create a map
my_map = folium.Map(location=[lat, lon], zoom_start=10)

# Add a layer for each satellite image of interest (before, during and after)
for i in landsat_sequence:

    # when was this image taken?
    date = ee.Image(landsat_list.get(i)).get('DATE_ACQUIRED').getInfo()

    my_map.add_ee_layer(ee.Image(landsat_list.get(i)).normalizedDifference(['SR_B5', 'SR_B4']), 
                        ndvi_parameters, 
                        name=date)
    
# Add a layer control panel to the map
folium.LayerControl(collapsed = False).add_to(my_map)

# Display the map.
display(my_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3023ec90d0fd0789dadf40fddfdf8551 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3023ec90d0fd0789dadf40fddfdf8551&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3023ec90d0fd0789dadf40fddfdf8551 = L.map(
#                 &quot;map_3023ec90d0fd0789dadf40fddfdf8551&quot;,
#                 {
#                     center: [39.444012, -121.833619],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e49d2297bfdf53e21c44dbe86800cf04 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e49d2297bfdf53e21c44dbe86800cf04.addTo(map_3023ec90d0fd0789dadf40fddfdf8551);
#
#
#             var tile_layer_b6e9e8f3d18aaa1e725ec468511be4b5 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/875075998925/maps/a3a4619931d72b51be92215d989cf462-8da08717a9b0e84c6591e7da1bcef9c2/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Map Data \u0026copy; \u003ca href=\&quot;https://earthengine.google.com/\&quot;\u003eGoogle Earth Engine\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b6e9e8f3d18aaa1e725ec468511be4b5.addTo(map_3023ec90d0fd0789dadf40fddfdf8551);
#
#
#             var tile_layer_cb3c62e23938abea6bc305fb432bc737 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/875075998925/maps/4e7479126fd00d0538f652c14076d175-08e18f0e316d6f54e0bd8739743c8e4f/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Map Data \u0026copy; \u003ca href=\&quot;https://earthengine.google.com/\&quot;\u003eGoogle Earth Engine\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cb3c62e23938abea6bc305fb432bc737.addTo(map_3023ec90d0fd0789dadf40fddfdf8551);
#
#
#             var tile_layer_fe6d63b395836c3d7c03fd817408fa7d = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/875075998925/maps/83a39f2c9e3224844508d70096be4873-8c24174ee3ffcb7aa303c87ef4c08406/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Map Data \u0026copy; \u003ca href=\&quot;https://earthengine.google.com/\&quot;\u003eGoogle Earth Engine\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fe6d63b395836c3d7c03fd817408fa7d.addTo(map_3023ec90d0fd0789dadf40fddfdf8551);
#
#
#             var layer_control_4c5a24a395cd164b4f21fbacf16fcaab_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_e49d2297bfdf53e21c44dbe86800cf04,
#                 },
#                 overlays :  {
#                     &quot;2018-10-07&quot; : tile_layer_b6e9e8f3d18aaa1e725ec468511be4b5,
#                     &quot;2018-11-08&quot; : tile_layer_cb3c62e23938abea6bc305fb432bc737,
#                     &quot;2018-12-26&quot; : tile_layer_fe6d63b395836c3d7c03fd817408fa7d,
#                 },
#             };
#             let layer_control_4c5a24a395cd164b4f21fbacf16fcaab = L.control.layers(
#                 layer_control_4c5a24a395cd164b4f21fbacf16fcaab_layers.base_layers,
#                 layer_control_4c5a24a395cd164b4f21fbacf16fcaab_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: false,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_3023ec90d0fd0789dadf40fddfdf8551);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Save the folium map as an html file

# %%
my_map.save('camp.html')

# %% [markdown]
# # Resources
#
# - [Google's Python Tutorial](https://developers.google.com/earth-engine/tutorials/community/intro-to-python-api-guiattard)
# - [Earth Lab](https://www.earthdatascience.org/courses/use-data-open-source-python/multispectral-remote-sensing/landsat-in-Python/)
